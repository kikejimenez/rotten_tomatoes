# %%
import cx_Oracle
import pandas as pd

usr ='movies_project'
pwd = 'intekglobal123'

#tns="db:1521/xe"
dsn = cx_Oracle.makedsn("db", 1521, service_name="xepdb1")

connection = cx_Oracle.connect(usr, pwd, dsn,encoding="UTF-8")


#check connectivity
cursor = connection.cursor()
cursor.execute("""   SELECT * FROM DUAL """)
for val in cursor:
    print("Values:", val)
# Out:
# Values: ('X',)

# %%
def q_max_names(colname):
    '''Select max number of names in all columns
    '''
    return f"""  
SELECT MAX(num_{colname}) FROM  (
SELECT  (LENGTH( "{colname}" ) - LENGTH(REPLACE( "{colname}" ,',','')) + 1) AS num_{colname} 
FROM (
SELECT TO_CHAR(TRIM("{colname}" )) AS "{colname}"   FROM ROTTEN_TOMATOES_RAW rtr 
WHERE "{colname}"  IS NOT NULL 
)
)
"""

# %%
q_column_names ="""
SELECT table_name, column_name, data_type, data_length
FROM USER_TAB_COLUMNS
WHERE table_name = 'ROTTEN_TOMATOES_RAW'
"""

cursor.execute(q_column_names)
dtypes_dic = {row[1]:row[2] for row in cursor.execute(q_column_names)}
dtypes_dic
# Out:
# {'YEAR': 'NUMBER',
#  'FILM_NAME': 'CLOB',
#  'RATING': 'CLOB',
#  'GENRE': 'CLOB',
#  'ORIGINAL_LANGUAGE': 'CLOB',
#  'DIRECTOR': 'CLOB',
#  'PRODUCER': 'CLOB',
#  'WRITER': 'CLOB',
#  'RELEASE_DATE_THEATERS': 'CLOB',
#  'RELEASE_DATE_STREAMING': 'CLOB',
#  'BOX_OFFICE_GROSS_USA': 'CLOB',
#  'RUNTIME': 'CLOB',
#  'PRODUCTION_CO': 'CLOB',
#  'SOUND_MIX': 'CLOB',
#  'VIEW_THE_COLLECTION': 'CLOB',
#  'SYNOPSIS': 'CLOB',
#  'CRITICS_CONSENSUS': 'CLOB',
#  'TOMATOMETER_SCORE': 'CLOB',
#  'TOMATOMETER_TOTAL_COUNT': 'CLOB',
#  'AUDIENCE_SCORE': 'CLOB',
#  'AUDIENCE_USER_RATINGS': 'CLOB',
#  'ASPECT_RATIO': 'CLOB'}

# %%
multi_valued_cols = ['DIRECTOR','PRODUCER','WRITER', 'PRODUCTION_CO']

# %%
#
one_to_many_columns = ['DIRECTOR','PRODUCER','WRITER','ORIGINAL_LANGUAGE', 'PRODUCTION_CO']

# %%
#Max names
max_names_multi_val_cols = {
    col: int(result[0])
    for col in multi_valued_cols for result in cursor.execute(q_max_names(col))
}
max_names_multi_val_cols
# Out:
# {'DIRECTOR': 5, 'PRODUCER': 8, 'WRITER': 8, 'PRODUCTION_CO': 22}

# %%
def q_split_comma_sep_vals(colname,positions):
    
    q_select_f = lambda pos:f"""select trim(regexp_substr("{colname}", '[^,]+', {pos}, 1))
    AS {colname}_{pos} 
    """
    
    q_select_cols = '\n'.join([q_select(pos) for pos in positions])
    return f"""
    
FROM ROTTEN_TOMATOES_RAW rtr 
"""

#f"""
#select TRIM(regexp_substr("{colname}", '(.*?)(,|$)', 1, {pos}, NULL, 1)) 
#AS {colname}_{pos} 
#FROM ROTTEN_TOMATOES_RAW rtr 
#"""

# %%
df

# %%
print(q_split_comma_sep_vals("WRITER",'1'))
# Out:
# select trim(regexp_substr("WRITER", '[^,]+', 1, 1))
# AS WRITER_1
# FROM ROTTEN_TOMATOES_RAW rtr

# %%
all([type(res) ==tuple for res in cursor.execute(q_split_comma_sep_vals("WRITER",'1'))])
# Out:
# True

# %%
#cursor.execute(q_split_comma_sep_vals("WRITER",'1'))
for r in cursor.execute(q_split_comma_sep_vals("WRITER",'1')):
    print(r[0])
# Out:
# Chang-dong Lee
# Aki Kaurismäki
# None
# None
# None
# None
# None
# None
# None
# Hossein Amini
# Ben Ripley
# Steve Kloves
# None
# Asghar Farhadi
# Steven Zaillian
# Jason Segel
# Josh Appelbaum
# Jeff Nichols
# Philip Shane
# Denis Osokin
# None
# Sean Durkin
# Alexander Payne
# John Logan
# Manish Pandey
# Valérie Beaugrand-Champagne
# Xavier Beauvois
# Joe Cornish
# None
# None
# John Logan
# Woody Allen
# Werner Herzog
# Annie Mumolo
# Tom McCarthy
# Will Reiser
# Drew Fellman
# Daisuke Tengan
# Dee Rees
# John Michael McDonagh
# Wim Wenders
# Céline Sciamma
# Andrew Haigh
# None
# Steven Zaillian
# None
# Scott Z. Burns
# Richard Ayoade
# J.C. Chandor
# None
# None
# George Clooney
# Apichatpong Weerasethakul
# None
# None
# None
# Chuan Lu
# Fred Cavayé
# None
# Abbas Kiarostami
# None
# John Logan
# None
# Stephen J. Anderson
# Ashley Miller
# Terrence Malick
# Gavin O'Connor
# None
# Alejandro Fadel
# Adrian Hodges
# Christopher Markus
# Mona Achache
# Mahamat-Saleh Haroun
# John Romano
# Paul Laverty
# Eli Craig
# Eric Eason
# Maryam Keshavarz
# Djo Munga
# None
# Michael Rapaport
# Phil Johnston
# Tom Wheeler
# J.J. Abrams
# Bridget O'Connor
# Mike Mills
# Rick Jaffa
# Jonathan Raymond
# Patrick deWitt
# Moira Buffini
# Ashley Miller
# François Ozon
# Jean Becker
# Jared Bush
# Taylor Sheridan
# Andrew Stanton
# Justin Marks
# Steve McQueen
# Diablo Cody
# Barry Jenkins
# Eric Heisserer
# Kenneth Lonergan
# Damien Chazelle
# Jonathan Aibel
# Dan Fogelman
# Jean Cosmos
# Lars von Trier
# Pedro Almodóvar
# Robert Eggers
# John Carney
# Mike Birbiglia
# None
# August Wilson
# Josh Campbell
# None
# Chris Weitz
# Ira Sachs
# Kelly Fremon
# Maren Ade
# Babak Anvari
# Christopher Markus
# Jim Jarmusch
# Jared Bush
# Marc Haimes
# Whit Stillman
# Shane Black
# Jon Spaihts
# Mia Hansen-Løve
# None
# Taika Waititi
# Guy Hibbert
# None
# None
# Anna Rose Holmer
# Jeff Nichols
# None
# Sabrina B. Karine
# Radu Jude
# James Napier Robertson
# Todd Komarnicki
# Rhett Reese
# Anna Biller
# Xavier Giannoli
# David Birke
# Jeremy Saulnier
# None
# Joel Coen
# Claire Paoletti
# None
# Na Hong-jin
# None
# None
# Kim Jee-woon
# Noah Oppenheim
# William Wheeler
# Asghar Farhadi
# None
# None
# Franck Ekinci
# David Lowery
# Trey Edward Shults
# Yorgos Lanthimos
# None
# David Kajganich
# Richard Linklater
# Irena Brignull
# Andrew Knight
# Nicholas Martin
